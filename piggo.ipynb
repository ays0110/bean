# %%
import dicom
import matplotlib.pyplot as plt

# %matplotlib inline

from pathlib import Path

# %%
dicom_files = [x for x in Path('./torso/rfmri/MR').iterdir() if x.is_file()]

# %%
blah = dicom.read_file(str(dicom_files[22]), force=True)
im = blah.pixel_array
plt.imshow(im)

# %%
im.shape
# Out:
# (128, 128)
